# %%
import numpy as np
a=np.load("S_normalized.npy")

# %%
a.shape
# Out:
# (2, 307, 307)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
b=a[0]
c=b[:,0]
a[0].shape,c.shape
# 绘制热力图
plt.figure(figsize=(25, 2.5))
sns.heatmap(c.reshape(1,-1), cmap='Reds',xticklabels=False,yticklabels=False,cbar_kws={"orientation": "horizontal", "aspect": 200,"ticks": []})
plt.savefig('heatmap.png')

# %%
import numpy as np
a=np.load("_.npy.npz")

# %%
a['arr_0'].shape
# Out:
# (9824, 3, 3)

# %%
mean_array = a['arr_0'].mean(axis=0)

# %%
mean_array
# Out:
# array([[0.43577093, 0.24445488, 0.3197741 ],
#        [0.46081176, 0.15066366, 0.3885245 ],
#        [0.3345113 , 0.3764885 , 0.2890004 ]], dtype=float32)

# %% [markdown]
# # cheb with sat

# %%
import numpy as np
a=np.load("T_k_with_at.npy.npz")
a=a["arr_0"]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
b=a[0]

# 绘制热力图
plt.figure(figsize=(25, 25))
sns.heatmap(b, cmap='Reds',xticklabels=False,yticklabels=False,cbar_kws={"orientation": "horizontal", "aspect": 200,"ticks": []})
plt.savefig('heatmap_.png')

# %%
b
# Out:
# array([[7.6314505e-19, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 9.0970445e-17, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 1.6448805e-18, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        ...,
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 9.3961638e-18,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         4.7968398e-18, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 2.5460293e-17]], dtype=float32)
